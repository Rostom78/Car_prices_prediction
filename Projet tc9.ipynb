# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('cleandataset2.csv')
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.seller_type.value_counts()
# Out:
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  torque  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00   190.0
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52   250.0
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00   117.0
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00   215.0
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20   107.0
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   float64
#  9   engine         7907 non-null   float64
#  10  max_power      7912 non-null   float64
#  11  torque         7906 non-null   float64
#  12  seats          7906 non-null   float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 825.6+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04    19.418783  1458.625016
# std       4.044249   8.062534e+05  5.655055e+04     4.037145   503.916303
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    16.780000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    19.300000  1248.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04    22.320000  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power       torque        seats
# count  7912.000000  7906.000000  7906.000000
# mean     91.517919   180.676069     5.416393
# std      35.822499   116.332100     0.959208
# min       0.000000    39.000000     2.000000
# 25%      68.050000   111.000000     5.000000
# ...

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        216
# torque           222
# seats            222
# dtype: int64

# %% [markdown]
# as we can see our data has 1100 null values

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %% [markdown]
# #        #Data Cleaning

# %%
#we start with data standarization :
# mileage engine max_power 
#we start with the fuel 
df["fuel"].value_counts()
# Out:
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: fuel, dtype: int64

# %%
#as we can see we have 3 types of fuel so we use the function below:
df.fuel = df.fuel.map({'Diesel':0, 'Petrol':1,'CNG':2,'LPG':3})
#from sklearn.preprocessing import LabelEncoder
#encoder=LabelEncoder()
#df['fuel']=encoder.fit_transform(df['fuel'])'''

# %%
df["seller_type"].value_counts()
# Out:
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
df.seller_type = df.seller_type.map({"Individual":0, "Dealer":1,"Trustmark Dealer":2})
#df['seller_type']=encoder.fit_transform(df['seller_type'])

# %%
#df['transmission']=encoder.fit_transform(df['transmission'])

# %%
df["seller_type"].isnull().sum()
# Out:
# 0

# %%
#we go now to the transmission :
df.transmission = df.transmission.map({"Manual":0, "Automatic":1})

# %%
df.owner.value_counts()
# Out:
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
df.owner= df.owner.map({"First Owner":1, "Second Owner":2,"Third Owner":3,"Fourth & Above Owner":4,"Test Drive Car":0})
#df['owner']=encoder.fit_transform(df['owner'])

# %%
#as we can see it's working
df.owner
# Out:
# 0       1
# 1       2
# 2       3
# 3       1
# 4       1
#        ..
# 8123    1
# 8124    4
# 8125    1
# 8126    1
# 8127    1
# Name: owner, Length: 8128, dtype: int64

# %%
#Maintenant on enleve les substrings suivantes de engine,mileage et max_power:

#df.engine=df.engine.str.strip(" CC")
#df.engine=df.engine.str.strip(' km/kg')

df.mileage=df.mileage.replace(' km/kg','')
#df.mileage=df.mileage.replace([' km/kg',' kmpl'],'')
df['max_power']=df['max_power'].replace(' bhp','')

# %%
#on verifie les données nulles qu'on a 
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        216
# torque           222
# seats            222
# dtype: int64

# %%
#on remplace les valeurs nulles:
df.seats.fillna(5,inplace=True)
df.seats.isnull().sum()
# Out:
# 0

# %%
df.engine=df.engine.astype(float)
df.engine.fillna(df.engine.mean(),inplace=True)
df.engine.isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   int64
#  5   seller_type    8128 non-null   int64
#  6   transmission   8128 non-null   int64
#  7   owner          8128 non-null   int64
#  8   mileage        7907 non-null   float64
#  9   engine         8128 non-null   float64
#  10  max_power      7912 non-null   float64
#  11  torque         7906 non-null   float64
#  12  seats          8128 non-null   float64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 825.6+ KB

# %%
#df.max_power.str.replace('','0')

df.mileage.fillna(df.mileage.mean(),inplace=True)
df.mileage.isnull().sum()
# Out:
# 0

# %%
df.max_power.fillna(df.max_power.mean(),inplace=True)    
df.max_power.isnull().sum()
# Out:
# 0

# %%
df.torque.fillna(df.torque.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
# Now we still have to do some feature engineering on our name:

# %%
#we're gonna extract the 2 first words of our noun as manufacturer and model:
manufacturer = []
modeles = []
for idx,name in zip(range(len(df['name'])),df['name']):
    manufacturer.append(name.split(" ")[0])
    modeles.append(name.split(" ")[1])
df['manufacturer'] = manufacturer
df['modeles'] = modeles

# %%
df
# Out:
#                               name  year  selling_price  km_driven  fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500     0
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2         Honda City 2017-2020 EXi  2006         158000     140000     1
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4           Maruti Swift VXI BSIII  2007         130000     120000     1
# ...                            ...   ...            ...        ...   ...
# 8123             Hyundai i20 Magna  2013         320000     110000     1
# 8124         Hyundai Verna CRDi SX  2007         135000     119000     0
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000     0
# 8126               Tata Indigo CR4  2013         290000      25000     0
# 8127               Tata Indigo CR4  2013         290000      25000     0
#
#       seller_type  transmission  owner  mileage  engine  max_power  torque  \
# ...

# %%
df.drop(['name'], axis=1, inplace=True)

# %%
df.manufacturer.value_counts()
# Out:
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: manufacturer, dtype: int64

# %%
#transforming our manufacturer and model using Labelencoder(same as ordinal encoder)

#to change the values from to numerical there are 2 methods
#automatically:
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['modeles']=encoder.fit_transform(df['modeles'])
df.head()
# Out:
#    year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0  2014         450000     145500     0            0             0      1
# 1  2014         370000     120000     0            0             0      2
# 2  2006         158000     140000     1            0             0      3
# 3  2010         225000     127000     0            0             0      1
# 4  2007         130000     120000     1            0             0      1
#
#    mileage  engine  max_power  torque  seats manufacturer  modeles
# 0    23.40  1248.0      74.00   190.0    5.0       Maruti      161
# 1    21.14  1498.0     103.52   250.0    5.0        Skoda      135
# 2    17.70  1497.0      78.00   117.0    5.0        Honda       36
# 3    23.00  1396.0      90.00   215.0    5.0      Hyundai      206
# 4    16.10  1298.0      88.20   107.0    5.0       Maruti      161

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['manufacturer']=encoder.fit_transform(df['manufacturer'])
df.head()
# Out:
#    year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0  2014         450000     145500     0            0             0      1
# 1  2014         370000     120000     0            0             0      2
# 2  2006         158000     140000     1            0             0      3
# 3  2010         225000     127000     0            0             0      1
# 4  2007         130000     120000     1            0             0      1
#
#    mileage  engine  max_power  torque  seats  manufacturer  modeles
# 0    23.40  1248.0      74.00   190.0    5.0            20      161
# 1    21.14  1498.0     103.52   250.0    5.0            27      135
# 2    17.70  1497.0      78.00   117.0    5.0            10       36
# 3    23.00  1396.0      90.00   215.0    5.0            11      206
# 4    16.10  1298.0      88.20   107.0    5.0            20      161

# %% [markdown]
# # Data viz:

# %%
#Now we're gonna visualise our data :

# %%
#we start by ploting data and seing relations and corellation between features.

# %%
import seaborn as sns
sns.distplot(df['max_power'],bins=10,hist=True,kde=True,color='blue')
# Out:
# C:\Users\rosto\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='max_power', ylabel='Density'>

# %%
r=df['seller_type'].value_counts()
r.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# -as we can see most of our sellers are individuals

# %%
r=df['transmission'].value_counts()
r.plot.bar()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.scatter(df["max_power"] ,df["selling_price"])

# %%
sns.catplot(x='transmission',y='selling_price',data=df)

# %%
df.corr()
# Out:
#                    year  selling_price  km_driven      fuel  seller_type  \
# year           1.000000       0.414092  -0.418006 -0.063381     0.234741
# selling_price  0.414092       1.000000  -0.225534 -0.205453     0.323047
# km_driven     -0.418006      -0.225534   1.000000 -0.240273    -0.194966
# fuel          -0.063381      -0.205453  -0.240273  1.000000     0.034963
# seller_type    0.234741       0.323047  -0.194966  0.034963     1.000000
# transmission   0.244707       0.588845  -0.201229  0.011879     0.355598
# owner         -0.513541      -0.243316   0.288681 -0.002501    -0.208762
# mileage        0.310383      -0.125454  -0.171426 -0.044051    -0.022422
# engine         0.017773       0.453567   0.203954 -0.484685     0.119382
# max_power      0.213282       0.744958  -0.037714 -0.300979     0.236716
# torque         0.087264       0.473949   0.077810 -0.505627     0.084634
# seats          0.011555       0.047425   0.219751 -0.337134    -0.071794
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
''''def plot_correlation_map(df):
    corr = df.corr()
    s,ax = plt.subplots( figsize =(12,10) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr,
        cmap=cmap,
        square=True,
        cbar_kws={'shrink': .9 },
        ax=ax,
        annot =True,
        annot_kws = {'fontsize': 12 }
        )
plot_correlation_map(df)'''
import matplotlib.pyplot as plt
f,ax = plt.subplots(figsize=(15,10))
correlation=sns.heatmap(df.corr(),annot=True, cmap = 'YlGnBu' ,linewidths=.1, fmt= '.2f',ax=ax)
img=correlation.get_figure()
img.savefig("corr.png")

# %% [raw]
# as we can see the more corelated data with the selling price are :
#     -max_power
#     -transmission
#     -torque
#     -engine

# %% [markdown]
# # Modeling

# %%
dict_score={}

# %%
#Decision Tree: 
#importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score

#features extraction
x=df.drop(["selling_price"], axis=1)
y= df["selling_price"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25,random_state=0)

# %%
from sklearn import metrics

decisiontree = tree.DecisionTreeRegressor(random_state=0)
decisiontree.fit(x_train, y_train) #fitting our model
y_pred=decisiontree.predict(x_test) # evaluating our model
m=metrics.r2_score(y_test,y_pred)
print(m)
dict_score["decisiontree"]=m
print(dict_score)
#Results.append[["dtc",m]]
# Out:
# 0.920860795561195
# {'decisiontree': 0.920860795561195}

# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor #Importing Random Forest Classifier
from sklearn import metrics # Importing metrics to test accuracy

# %%
#x=df.drop(["selling_price","mileage"], axis=1)
x=df[['year','transmission','max_power','engine']]
y= df["selling_price"]
#splitting data
 #target
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.3) #splitting data with test size of 30%

# %%
randomforest=RandomForestRegressor(max_depth=10,random_state=123) #Creating a random forest 
randomforest.fit(x_train, y_train) #Training our model
y_pred=randomforest.predict(x_test) #testing our model
print("MSE: ", metrics.mean_squared_error(y_test, y_pred))
print("R squared: ", metrics.r2_score(y_test,y_pred))
m2=metrics.r2_score(y_test,y_pred)
dict_score["randomforest"]=m2
print(dict_score)
# Out:
# MSE:  20214483329.760838
# R squared:  0.9721363174940769
# {'decisiontree': 0.920860795561195, 'randomforest': 0.9721363174940769, 'lreg': 0.5550391295611702, 'multilinear': 0.663657448376076, 'polynomial': 0.9151115429712625, 'xgb_r': 0.9667713197839425}

# %% [raw]
# as we can see the random forest algorithm is giving us a better r2 score then the decision tree

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
#extract x and y from our data (were going to try )
#trying the linear regression with the more corelated features with our output
x=df["max_power"].values[:,np.newaxis]
y=df["selling_price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=4) #splitting datawith test size of 35%
#applying linear regression on our data
lreg=LinearRegression() #build linear regression model
lreg.fit(x_train,y_train) #fitting the training data
predicted=lreg.predict(x_test) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
m3=metrics.r2_score(y_test,predicted)
dict_score["lreg"]=m3
print(dict_score)
# Out:
# MSE 295402416592.5302
# R squared 0.5675335390394621
# {'decisiontree': 0.920860795561195, 'randomforest': 0.9721363174940769, 'lreg': 0.5675335390394621, 'multilinear': 0.663657448376076, 'polynomial': 0.9151115429712625, 'xgb_r': 0.9667713197839425}

# %%
plt.scatter(x_test.squeeze(),y_test,label="data points")
plt.title("Linear Regression")
plt.ylabel("selling_price")
plt.xlabel("max_power")
plt.plot(x_test,lreg.predict(x_test),color="k")
plt.show()

# %%
#now we're gonna try to apply it on more data using the multi linear regression 
#extract x and y from our data (were going to try )
#x=df.drop(["selling_price"], axis=1)
x=df[["year","transmission","engine","max_power"]]
y=df["selling_price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting datawith test size of 35%

#applying linear regression on our data
multilinear=LinearRegression() #build linear regression model
multilinear.fit(x_train,y_train) #fitting the training data
predicted=multilinear.predict(x_test) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
m4=metrics.r2_score(y_test,predicted)
dict_score["multilinear"]=m4

print(dict_score)
# Out:
# MSE 235842401095.2272
# R squared 0.6475622127319522
# {'decisiontree': 0.920860795561195, 'randomforest': 0.9721363174940769, 'lreg': 0.5675335390394621, 'multilinear': 0.6475622127319522, 'polynomial': 0.9151115429712625, 'xgb_r': 0.9667713197839425}

# %%
#now we're gonna try the polynomial regression
from sklearn.preprocessing import PolynomialFeatures

y= df["selling_price"].values
x=df.drop(["selling_price"],axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.40, random_state=40) #splitting data
lg=LinearRegression()
polynomial=PolynomialFeatures(degree=2)
x_train_fit = polynomial.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = polynomial.fit_transform(x_test)
predicted = lg.predict(x_test_)
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
m5=metrics.r2_score(y_test,predicted)
dict_score["polynomial"]=m5
print(dict_score)
# Out:
# MSE:  57476017868.440025
# R squared:  0.9168541014614556
# {'decisiontree': 0.920860795561195, 'randomforest': 0.9721363174940769, 'lreg': 0.5675335390394621, 'multilinear': 0.6475622127319522, 'polynomial': 0.9168541014614556, 'xgb_r': 0.9667713197839425}

# %%
#scaling (standarize our data using standard scaler )/box plot and visualising outliers
df2=pd.read_csv("cleandataset2.csv")
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
model = scaler.fit(df)
df3 = model.transform(df)

# %%
df2=df
df2= df2.loc[~(df['year']<2002) ]
df2
# Out:
#       year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0     2014         450000     145500     0            0             0      1
# 1     2014         370000     120000     0            0             0      2
# 2     2006         158000     140000     1            0             0      3
# 3     2010         225000     127000     0            0             0      1
# 4     2007         130000     120000     1            0             0      1
# ...    ...            ...        ...   ...          ...           ...    ...
# 7673  2017         750000      30000     0            0             0      1
# 7674  2015         300000      19800     1            0             0      1
# 7675  2011         250000      90000     0            0             0      3
# 7676  2014         335000      33033     1            1             0      1
# 7677  2015         465000      63063     1            1             1      1
#
# ...

# %%
import xgboost as xg
from sklearn.metrics import mean_squared_error as MSE
 

train_x, test_x, train_y, test_y = train_test_split(x, y,
                      test_size = 0.3, random_state = 123)
 
# Instantiation
xgb_r = xg.XGBRegressor(objective ='reg:linear',
                  n_estimators = 10, seed = 123)
 
# Fitting the model
xgb_r.fit(train_x, train_y)
 
# Predict the model
pred = xgb_r.predict(test_x)
 
# RMSE Computation
rmse = np.sqrt(MSE(test_y, pred))
#print("RMSE : % f" %(rmse))
metrics.r2_score(test_y,pred)

m6=metrics.r2_score(test_y,pred)
dict_score["xgb_r"]=m6
print(dict_score)
# Out:
# [22:06:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-030221e36e1a46bfb-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# {'decisiontree': 0.920860795561195, 'randomforest': 0.9721363174940769, 'lreg': 0.5675335390394621, 'multilinear': 0.6475622127319522, 'polynomial': 0.9168541014614556, 'xgb_r': 0.9582081408982528}

# %%
dict_score
# Out:
# {'decisiontree': 0.920860795561195,
#  'randomforest': 0.9721363174940769,
#  'lreg': 0.5675335390394621,
#  'multilinear': 0.6475622127319522,
#  'polynomial': 0.9168541014614556,
#  'xgb_r': 0.9582081408982528}

# %%
import seaborn as sns
names = list(dict_score.keys())
values = list(dict_score.values())
plt.figure(figsize=(12,12)) 
plt.bar(range(len(dict_score)), values, tick_label=names)
plt.xticks(rotation=90)
plt.xlabel("the model ")
plt.ylabel("r2. quare")
plt.title("The r2square of every model used")

plt.savefig('barplot.png')
plt.show()

# %% [raw]
# As we can see after trying our 6 models(Decision tree,Random forest,Linear regression ,Multilinear regression,Polinomial regression ,XGboost), we can see that the algorithm that gives us the best r2 square is the random forest algorithm

# %%
data2=df
data3=data2.tail(500)
data3
# Out:
#       year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 7178  2016        2000000      70000     1            0             1      1
# 7179  2010         175000      83000     1            0             0      2
# 7180  2015         440000      50000     0            0             0      1
# 7181  2012         254999      90000     0            0             0      1
# 7182  2018         530000      65000     1            0             0      1
# ...    ...            ...        ...   ...          ...           ...    ...
# 7673  2017         750000      30000     0            0             0      1
# 7674  2015         300000      19800     1            0             0      1
# 7675  2011         250000      90000     0            0             0      3
# 7676  2014         335000      33033     1            1             0      1
# 7677  2015         465000      63063     1            1             1      1
#
# ...

# %%
data2.drop(data2.tail(450).index,
        inplace = True)

# %%
x=data2.drop(["selling_price"], axis=1)
y= data2["selling_price"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25,random_state=0)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
dtc = tree.DecisionTreeRegressor(random_state=0)
dtc.fit(x_train, y_train) #fitting our model
y_pred=dtc.predict(x_test) # evaluating our model
metrics.r2_score(y_test,y_pred)
# Out:
# 0.9417693980193506

# %%
true_values = df['selling_price']
data2= df.drop(columns='selling_price',axis=1)

# %%
predicts_test = dtc.predict(data2)
metrics.r2_score(true_values, predicts_test)
# Out:
# 0.9833981251724846

# %% [markdown]
# #on remarque que notre modéle ne fait pas d'overfitting .
# le random forest algorithm est donc le meilleur modéle a utiliser

# %%
import pickle
pickle.dump(dtc,open("model.pkl","wb"))
pickle.dump(encoder,open("encoder.pkl","wb"))

# %%
#we want to controle the comment section by using an existing libraring and using it like below:
from better_profanity import profanity 
text="you are shit"
censored=profanity.censor(text)
censored
# Out:
# 'you are ****'

# %% [raw]
# #on veut traiter les commentaires de cette facon , mais en utilisant NLP.
# Ps:(la bibliothéque utiliser ici sert a montrer ce qu'on voudrais faire)
